# %%
print("Hello World")
# Out:
# Hello World

# %%
from pandas_datareader import data as web
df = web.DataReader("AAPL", "google", "2016/1/1", "2017/1/1")
df.head()
# Out:
#                                                    #guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh  \
# <!doctype html><html itemscope="" itemtype="htt...
# news                                                                             financial statements
# time stock quotes                                              historical charts &amp; financial news
# financials                                           technicals and opinions.</span><br></div></di...
# information from CNBC.</span><br></div></div><d...                                             charts
# chains with call and put prices                                           viewable by expiration date
#
# ...
